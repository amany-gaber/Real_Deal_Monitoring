# %%
import pandas as pd

# %%
df = pd.read_csv('Data/prices_2025-12-25.csv')

# %%
df.head()
# Out:
#          date source category            search_query  page  \
# 0  2025-12-25  jumia  Grocery  ['oil', 'cooking oil']     1
# 1  2025-12-25  jumia  Grocery  ['oil', 'cooking oil']     1
# 2  2025-12-25  jumia  Grocery  ['oil', 'cooking oil']     1
# 3  2025-12-25  jumia  Grocery  ['oil', 'cooking oil']     1
# 4  2025-12-25  jumia  Grocery  ['oil', 'cooking oil']     1
#
#                item_id          brand  \
# 0  KI299FF381XKXNAFAMZ  Kitchen Tools
# 1  GE810FF22J0OLNAFAMZ        Generic
# 2  GE810FF1UX05JNAFAMZ        Generic
# 3  GE810FF2OTYMRNAFAMZ        Generic
# 4  GE810FF2GKJ47NAFAMZ        Generic
#
#                                        category_path  \
# 0  Grocery/Cooking & Baking/Vinegars & Sprays/Non...
# 1  Grocery/Cooking & Baking/Vinegars & Sprays/Non...
# 2  Grocery/Cooking & Baking/Vinegars & Sprays/Non...
# 3  Grocery/Cooking & Baking/Vinegars & Sprays/Non...
# 4  Grocery/Cooking & Baking/Vinegars & Sprays/Non...
#
# ...

# %%
df.shape
# Out:
# (22712, 16)

# %%
df['item_id'].drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (22712, 16)
